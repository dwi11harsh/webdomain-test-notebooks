# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from baml_client import b

# %%
result = b.PlanNextjsProjectGenerationSteps(user_prompt="Create a todo app")
print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 result = b.PlanNextjsProjectGenerationSteps(user_prompt="Create a todo app")
#       2 print(result)
#
# AttributeError: 'BamlSyncClient' object has no attribute 'PlanNextjsProjectGenerationSteps'
